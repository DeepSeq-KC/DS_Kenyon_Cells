# %%
import pandas as pd
import numpy as np
import sys
import hdbscan

# %%
# Load up code to run ICIM
# Available from : https://github.com/felixhorns/FlyPN
sys.path.append("../code/ICIM")
import sct
reload(sct)
# Used because of nature of ICIM library
pd.options.mode.chained_assignment = None  # default='warn'

# %%
# Set up to pull out the list of genes in the pruned expression table
df = pd.read_csv("../data/02_filtered_kenyon_cells/CLEAN_LOG2TRANSFORM_kenyon_cells.csv", index_col='symbol')

# %%
# ended up with a random row nan whose entire row is 0 counts - FAKE GENE
print('Shape of df with nan index : ' + str(df[df.index.isna()].shape))
print('total sum of expression values : ' + str(sum(df[df.index.isna()].iloc[0])))
print('drop row')
df = df[~df.index.isna()]
# Out:
# Shape of df with nan index : (1, 2848)
# total sum of expression values : 0.0
# drop row

# %%
df.shape
# Out:
# (17472, 2848)

# %%
# Will generate each list of genes seperately in case it is necc. to analyze them seperately.
# After creation will compile them all into a seperate list

gene_list = []

# %%
# Nicotinic receptor component subtype genes
# Keep the gene (index column) only for those genes which contain the 'nAChR'
# These genes are discussed at http://flybase.org/reports/FBgg0000202.html
nAChR = list(df[df.index.str.contains('nAChR', na=False)].index)

# %%
# Muscarinic receptor component subtype genes
# Keep the gene (index column) only for those genes which contain the 'mAChR'
# These genes are discussed at http://flybase.org/reports/FBgg0000187.html
mAChR = list(df[df.index.str.contains('mAChR', na=False)].index)

# %%
# Defective proboscis extension reponse genes
# Keep the gene (index column) only for those genes which contain the 'dpr'
# These genes are discussed at http://flybase.org/reports/FBgg0000529.html
dpr = list(df[df.index.str.contains('dpr', na=False)].index)

# %%
# Dpr interacting proteins
# These come in two batches - DIP & two unnamed genes ['CG31814', 'CG45781']
# These genes are discussed at http://flybase.org/reports/FBgg0000530
dip = list(df[df.index.str.contains('DIP-', na=False)].index) + list(df[df.index.isin(['CG31814', 'CG45781'])].index)

# %%
dscam = list(df[df.index.str.contains('Dscam', na=False)].index)

# %%
for geneset in [nAChR, mAChR, dpr, dip, dscam]:
    gene_list.extend(geneset)

# %%
# TSNE Projection will be completed with # genes:
len(gene_list)
# Out:
# 49

# %%
# Generate a filtered df based on these genes
f_df = df.copy(deep=True)
f_df = f_df.loc[gene_list]

# %%
f_df.shape
# Out:
# (49, 2848)

# %%
# Check to make sure each gene is present in at least 3 cells
def check_min_num_cells(row):
    num_pos = 0
    for gene_count in row:
        if gene_count > 0:
            num_pos += 1
            if num_pos >= 3:
                return True
    return False
   

min_num_cells = f_df.apply(check_min_num_cells, axis=1)
f_df = f_df[min_num_cells]

# %%
f_df.shape
# Out:
# (47, 2848)

# %%
# This is a cell which has no expression for the associated synaptic organizing genes
# It has to be removed from both the unfiltered/filtered df AND the metadata df
f_df.loc[:,f_df.apply(sum) == 0].columns
# Out:
# Index([u'CTACACCTCAGAGGTG-DGRP-551_9d_r1'], dtype='object')

# %%
# remove any cells which have zero counts for all genes in gene_list
df = df.drop('CTACACCTCAGAGGTG-DGRP-551_9d_r1', axis=1)
f_df = f_df.drop('CTACACCTCAGAGGTG-DGRP-551_9d_r1', axis=1)

# %%
df.shape
# Out:
# (17472, 2847)

# %%
f_df.shape
# Out:
# (47, 2847)

# %%
# load up metadata that corresponds to full df
metadata = pd.read_csv("../data/02_filtered_kenyon_cells/metadata_kenyon_cells.csv")
metadata = metadata.set_index("CellID")

# %%
metadata = metadata.drop('CTACACCTCAGAGGTG-DGRP-551_9d_r1')

# %%
metadata.shape
# Out:
# (2847, 8)

# %%
# Calculate TSNE
reload(sct)
from sklearn.manifold import TSNE
myTSNE = sct.TSNE(f_df, df, metadata)
myTSNE.calc_TSNE(perplexity=10, learning_rate=250, early_exaggeration=4.0, method="exact", random_state=1)
# Out:
# [t-SNE] Computed conditional probabilities for sample 1000 / 2847
# [t-SNE] Computed conditional probabilities for sample 2000 / 2847
# [t-SNE] Computed conditional probabilities for sample 2847 / 2847
# [t-SNE] Mean sigma: 0.116605
# [t-SNE] Iteration 50: error = 25.9108090, gradient norm = 0.0070685 (50 iterations in 14.823s)
# [t-SNE] Iteration 100: error = 25.7676472, gradient norm = 0.0004148 (50 iterations in 14.791s)
# [t-SNE] Iteration 150: error = 25.7689364, gradient norm = 0.0001069 (50 iterations in 14.654s)
# [t-SNE] Iteration 200: error = 25.7696320, gradient norm = 0.0000370 (50 iterations in 14.673s)
# [t-SNE] Iteration 250: error = 25.7699342, gradient norm = 0.0000196 (50 iterations in 14.973s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 25.769934
# [t-SNE] Iteration 300: error = 3.3168265, gradient norm = 0.0016014 (50 iterations in 14.786s)
# [t-SNE] Iteration 350: error = 3.0080594, gradient norm = 0.0006648 (50 iterations in 14.660s)
# [t-SNE] Iteration 400: error = 2.8700291, gradient norm = 0.0004323 (50 iterations in 14.625s)
# [t-SNE] Iteration 450: error = 2.7933328, gradient norm = 0.0003236 (50 iterations in 14.711s)
# [t-SNE] Iteration 500: error = 2.7442656, gradient norm = 0.0002434 (50 iterations in 15.963s)
# [t-SNE] Iteration 550: error = 2.7106273, gradient norm = 0.0001972 (50 iterations in 21.396s)
# [t-SNE] Iteration 600: error = 2.6856350, gradient norm = 0.0001703 (50 iterations in 16.279s)
# [t-SNE] Iteration 650: error = 2.6668973, gradient norm = 0.0001374 (50 iterations in 15.969s)
# [t-SNE] Iteration 700: error = 2.6523704, gradient norm = 0.0001178 (50 iterations in 15.617s)
# [t-SNE] Iteration 750: error = 2.6408322, gradient norm = 0.0001032 (50 iterations in 17.443s)
# [t-SNE] Iteration 800: error = 2.6315726, gradient norm = 0.0000855 (50 iterations in 14.935s)
# [t-SNE] Iteration 850: error = 2.6239222, gradient norm = 0.0000777 (50 iterations in 14.674s)
# [t-SNE] Iteration 900: error = 2.6174888, gradient norm = 0.0000711 (50 iterations in 20.206s)
# [t-SNE] Iteration 950: error = 2.6121273, gradient norm = 0.0000618 (50 iterations in 19.098s)
# [t-SNE] Iteration 1000: error = 2.6076887, gradient norm = 0.0000578 (50 iterations in 15.315s)
# [t-SNE] Error after 1000 iterations: 2.607689

# %%
# Using HDBSCAN to call clusters automatically, generate metadata for them
clusterer = hdbscan.HDBSCAN(min_cluster_size=30, min_samples=3).fit(myTSNE.X_tsne)
labels_HDBSCAN = clusterer.labels_

# %%
print "Clusters", max(labels_HDBSCAN)+1
# Out:
# Clusters 32

# %%
zero_axis = myTSNE.X_tsne[:,0]
one_axis = myTSNE.X_tsne[:,1]
myTSNE.df_libs['x'] = zero_axis
myTSNE.df_libs['y'] = one_axis
myTSNE.df_libs['hdb_clust'] = labels_HDBSCAN
myTSNE.df_libs.to_csv("../data/05_synapse_organizing_gene_TSNE_gen/KC_synapse_organizing_gene_TSNE_data.csv")

# %%
# Out:
#                                  Age  Gender  Genotype         Replicate  \
# CellID
# ACATACGAGGGCTTCC-DGRP-551_0d_r1    0  Female  DGRP-551  DGRP-551_0d_Rep1
# ACCCACTTCACTCTTA-DGRP-551_0d_r1    0  Female  DGRP-551  DGRP-551_0d_Rep1
# ACCGTAAAGATAGTCA-DGRP-551_0d_r1    0    Male  DGRP-551  DGRP-551_0d_Rep1
# ACTTACTAGTGGTAAT-DGRP-551_0d_r1    0    Male  DGRP-551  DGRP-551_0d_Rep1
# ACTTGTTCATGGTTGT-DGRP-551_0d_r1    0    Male  DGRP-551  DGRP-551_0d_Rep1
# ACTTTCATCAATAAGG-DGRP-551_0d_r1    0    Male  DGRP-551  DGRP-551_0d_Rep1
# AGATCTGCAACAACCT-DGRP-551_0d_r1    0    Male  DGRP-551  DGRP-551_0d_Rep1
# AGATCTGTCTACTCAT-DGRP-551_0d_r1    0    Male  DGRP-551  DGRP-551_0d_Rep1
# AGCGGTCCATTTCACT-DGRP-551_0d_r1    0  Female  DGRP-551  DGRP-551_0d_Rep1
# AGCTCTCGTTTGACTG-DGRP-551_0d_r1    0  Female  DGRP-551  DGRP-551_0d_Rep1
# AGGTCATGTCAGAATA-DGRP-551_0d_r1    0  Female  DGRP-551  DGRP-551_0d_Rep1
# ATCCACCCAGACACTT-DGRP-551_0d_r1    0    Male  DGRP-551  DGRP-551_0d_Rep1
# ATGGGAGAGGAATGGA-DGRP-551_0d_r1    0    Male  DGRP-551  DGRP-551_0d_Rep1
# ATGTGTGGTCACCCAG-DGRP-551_0d_r1    0    Male  DGRP-551  DGRP-551_0d_Rep1
# ATTGGACAGCTTATCG-DGRP-551_0d_r1    0  Female  DGRP-551  DGRP-551_0d_Rep1
# CACCACTCACTCAGGC-DGRP-551_0d_r1    0    Male  DGRP-551  DGRP-551_0d_Rep1
# CAGATCACAGATCTGT-DGRP-551_0d_r1    0  Female  DGRP-551  DGRP-551_0d_Rep1
# CAGCTGGTCTACTCAT-DGRP-551_0d_r1    0  Female  DGRP-551  DGRP-551_0d_Rep1
# CAGGTGCAGGGATGGG-DGRP-551_0d_r1    0    Male  DGRP-551  DGRP-551_0d_Rep1
# CCGTGGACAAAGGTGC-DGRP-551_0d_r1    0    Male  DGRP-551  DGRP-551_0d_Rep1
# CCTAAAGGTCAGATAA-DGRP-551_0d_r1    0  Female  DGRP-551  DGRP-551_0d_Rep1
# CCTCAGTCATTATCTC-DGRP-551_0d_r1    0    Male  DGRP-551  DGRP-551_0d_Rep1
# CCTCAGTTCCAAGCCG-DGRP-551_0d_r1    0    Male  DGRP-551  DGRP-551_0d_Rep1
# CGAGAAGAGAATAGGG-DGRP-551_0d_r1    0  Female  DGRP-551  DGRP-551_0d_Rep1
# CGATTGATCCGAACGC-DGRP-551_0d_r1    0    Male  DGRP-551  DGRP-551_0d_Rep1
# CGTCACTGTCGAGATG-DGRP-551_0d_r1    0    Male  DGRP-551  DGRP-551_0d_Rep1
# CTACATTAGCTGCCCA-DGRP-551_0d_r1    0    Male  DGRP-551  DGRP-551_0d_Rep1
# CTAGCCTCATACGCCG-DGRP-551_0d_r1    0    Male  DGRP-551  DGRP-551_0d_Rep1
# CTCATTAAGATCTGAA-DGRP-551_0d_r1    0  Female  DGRP-551  DGRP-551_0d_Rep1
# CTCGAGGGTAACGACG-DGRP-551_0d_r1    0    Male  DGRP-551  DGRP-551_0d_Rep1
# ...                              ...     ...       ...               ...
# TGCTGCTAGGTGCACA-w1118_9d_r3       9  Female     W1118     W1118_9d_Rep3
# TGGACGCTCAAACGGG-w1118_9d_r3       9  Female     W1118     W1118_9d_Rep3
# TGGACGCTCGTATCAG-w1118_9d_r3       9  Female     W1118     W1118_9d_Rep3
# TGGCGCATCGATAGAA-w1118_9d_r3       9    Male     W1118     W1118_9d_Rep3
# TGGGAAGGTCTGCCAG-w1118_9d_r3       9  Female     W1118     W1118_9d_Rep3
# TGGTTCCGTGACGCCT-w1118_9d_r3       9    Male     W1118     W1118_9d_Rep3
# TTAACTCAGGCTCAGA-w1118_9d_r3       9    Male     W1118     W1118_9d_Rep3
# TTAGGACGTACTTGAC-w1118_9d_r3       9    Male     W1118     W1118_9d_Rep3
# TTCCCAGCATACAGCT-w1118_9d_r3       9    Male     W1118     W1118_9d_Rep3
# TTGAACGGTCTAAAGA-w1118_9d_r3       9    Male     W1118     W1118_9d_Rep3
# TTGACTTGTCGTCTTC-w1118_9d_r3       9  Female     W1118     W1118_9d_Rep3
# TTGACTTTCAGCGATT-w1118_9d_r3       9  Female     W1118     W1118_9d_Rep3
# TTGTAGGAGGAGCGAG-w1118_9d_r3       9  Female     W1118     W1118_9d_Rep3
# TTTGCGCGTTAAGACA-w1118_9d_r3       9    Male     W1118     W1118_9d_Rep3
# ACGATACCAAACAACA-w1118_15d_r1     15  Female     W1118    W1118_15d_Rep1
# CGCCAAGCATTTCACT-w1118_15d_r1     15  Female     W1118    W1118_15d_Rep1
# CTAAGACCAGCTGCTG-w1118_15d_r1     15  Female     W1118    W1118_15d_Rep1
# CTACCCACAAGCCCAC-w1118_15d_r1     15  Female     W1118    W1118_15d_Rep1
# GAACCTAGTCCGACGT-w1118_15d_r1     15    Male     W1118    W1118_15d_Rep1
# GAGTCCGAGGTGCAAC-w1118_15d_r1     15  Female     W1118    W1118_15d_Rep1
# GGCAATTCATGGATGG-w1118_15d_r1     15  Female     W1118    W1118_15d_Rep1
# GTCCTCAGTTGCGCAC-w1118_15d_r1     15  Female     W1118    W1118_15d_Rep1
# GTGCAGCGTACCGTAT-w1118_15d_r1     15    Male     W1118    W1118_15d_Rep1
# TATGCCCTCTATGTGG-w1118_15d_r1     15  Female     W1118    W1118_15d_Rep1
# TCATTACAGAGGTTGC-w1118_15d_r1     15    Male     W1118    W1118_15d_Rep1
# TCGAGGCAGCTATGCT-w1118_15d_r1     15  Female     W1118    W1118_15d_Rep1
# TTCTACATCAGTGTTG-w1118_15d_r1     15  Female     W1118    W1118_15d_Rep1
# AAGTCTGTCTGGTTCC-w1118_30d_r1     30    Male     W1118    W1118_30d_Rep1
# ACATACGTCGGATGGA-w1118_30d_r1     30    Male     W1118    W1118_30d_Rep1
# GAAATGACAAGACACG-w1118_30d_r1     30  Female     W1118    W1118_30d_Rep1
#
#                                  nGene    nUMI  cell_type_id  is_kc  \
# CellID
# ACATACGAGGGCTTCC-DGRP-551_0d_r1   1328  3340.0           8.0      1
# ACCCACTTCACTCTTA-DGRP-551_0d_r1   1613  4580.0           8.0      1
# ACCGTAAAGATAGTCA-DGRP-551_0d_r1   1466  4349.0          22.0      1
# ACTTACTAGTGGTAAT-DGRP-551_0d_r1   1174  2942.0           8.0      1
# ACTTGTTCATGGTTGT-DGRP-551_0d_r1   1410  3620.0           8.0      1
# ACTTTCATCAATAAGG-DGRP-551_0d_r1   1378  3995.0           8.0      1
# AGATCTGCAACAACCT-DGRP-551_0d_r1   1578  4379.0           8.0      1
# AGATCTGTCTACTCAT-DGRP-551_0d_r1   1592  4639.0          28.0      1
# AGCGGTCCATTTCACT-DGRP-551_0d_r1   1165  2920.0          28.0      1
# AGCTCTCGTTTGACTG-DGRP-551_0d_r1   1368  3426.0           8.0      1
# AGGTCATGTCAGAATA-DGRP-551_0d_r1   1378  3435.0           8.0      1
# ATCCACCCAGACACTT-DGRP-551_0d_r1   1418  3696.0          22.0      1
# ATGGGAGAGGAATGGA-DGRP-551_0d_r1   1311  3261.0          22.0      1
# ATGTGTGGTCACCCAG-DGRP-551_0d_r1   1280  3444.0          22.0      1
# ATTGGACAGCTTATCG-DGRP-551_0d_r1   1090  2538.0           8.0      1
# CACCACTCACTCAGGC-DGRP-551_0d_r1   1387  3410.0          28.0      1
# CAGATCACAGATCTGT-DGRP-551_0d_r1   1484  4031.0           8.0      1
# CAGCTGGTCTACTCAT-DGRP-551_0d_r1   1334  3164.0          22.0      1
# CAGGTGCAGGGATGGG-DGRP-551_0d_r1   1459  4092.0           8.0      1
# CCGTGGACAAAGGTGC-DGRP-551_0d_r1   1650  4894.0          22.0      1
# CCTAAAGGTCAGATAA-DGRP-551_0d_r1   1362  3336.0           8.0      1
# CCTCAGTCATTATCTC-DGRP-551_0d_r1   1537  4279.0           8.0      1
# CCTCAGTTCCAAGCCG-DGRP-551_0d_r1   1250  2898.0           8.0      1
# CGAGAAGAGAATAGGG-DGRP-551_0d_r1   1541  5230.0          22.0      1
# CGATTGATCCGAACGC-DGRP-551_0d_r1   1457  3965.0           8.0      1
# CGTCACTGTCGAGATG-DGRP-551_0d_r1   1320  3846.0          22.0      1
# CTACATTAGCTGCCCA-DGRP-551_0d_r1   1542  4886.0          22.0      1
# CTAGCCTCATACGCCG-DGRP-551_0d_r1   1512  4115.0          28.0      1
# CTCATTAAGATCTGAA-DGRP-551_0d_r1   1022  2257.0          28.0      1
# CTCGAGGGTAACGACG-DGRP-551_0d_r1   1373  3459.0          28.0      1
# ...                                ...     ...           ...    ...
# TGCTGCTAGGTGCACA-w1118_9d_r3       997  1984.0          22.0      1
# TGGACGCTCAAACGGG-w1118_9d_r3       720  1218.0          22.0      1
# TGGACGCTCGTATCAG-w1118_9d_r3      1146  2518.0           8.0      1
# TGGCGCATCGATAGAA-w1118_9d_r3       859  1680.0           8.0      1
# TGGGAAGGTCTGCCAG-w1118_9d_r3      1005  1817.0          28.0      1
# TGGTTCCGTGACGCCT-w1118_9d_r3      1103  3096.0           8.0      1
# TTAACTCAGGCTCAGA-w1118_9d_r3       861  1501.0           8.0      1
# TTAGGACGTACTTGAC-w1118_9d_r3       865  1658.0           8.0      1
# TTCCCAGCATACAGCT-w1118_9d_r3      1014  2293.0          22.0      1
# TTGAACGGTCTAAAGA-w1118_9d_r3      1057  2215.0          22.0      1
# TTGACTTGTCGTCTTC-w1118_9d_r3      1097  2357.0          28.0      1
# TTGACTTTCAGCGATT-w1118_9d_r3       883  1639.0          22.0      1
# TTGTAGGAGGAGCGAG-w1118_9d_r3       774  1483.0           8.0      1
# TTTGCGCGTTAAGACA-w1118_9d_r3      1073  2233.0          28.0      1
# ACGATACCAAACAACA-w1118_15d_r1      617  1254.0           8.0      1
# CGCCAAGCATTTCACT-w1118_15d_r1      387   702.0           8.0      1
# CTAAGACCAGCTGCTG-w1118_15d_r1      777  1508.0           8.0      1
# CTACCCACAAGCCCAC-w1118_15d_r1      522   920.0          22.0      1
# GAACCTAGTCCGACGT-w1118_15d_r1      737  1513.0          28.0      1
# GAGTCCGAGGTGCAAC-w1118_15d_r1      980  2392.0           8.0      1
# GGCAATTCATGGATGG-w1118_15d_r1      761  1538.0           8.0      1
# GTCCTCAGTTGCGCAC-w1118_15d_r1      439   817.0           8.0      1
# GTGCAGCGTACCGTAT-w1118_15d_r1      578  1133.0          22.0      1
# TATGCCCTCTATGTGG-w1118_15d_r1      888  1922.0           8.0      1
# TCATTACAGAGGTTGC-w1118_15d_r1      751  1457.0          22.0      1
# TCGAGGCAGCTATGCT-w1118_15d_r1      561  1098.0           8.0      1
# TTCTACATCAGTGTTG-w1118_15d_r1      747  1509.0          28.0      1
# AAGTCTGTCTGGTTCC-w1118_30d_r1      985  1710.0          28.0      1
# ACATACGTCGGATGGA-w1118_30d_r1      686  1077.0           8.0      1
# GAAATGACAAGACACG-w1118_30d_r1     1133  2532.0           8.0      1
#
#                                          x          y  hdb_clust
# CellID
# ACATACGAGGGCTTCC-DGRP-551_0d_r1 -96.505142  14.263201         -1
# ACCCACTTCACTCTTA-DGRP-551_0d_r1 -84.053337  26.400314         -1
# ACCGTAAAGATAGTCA-DGRP-551_0d_r1 -24.615211 -59.094845          1
# ACTTACTAGTGGTAAT-DGRP-551_0d_r1  38.734455 -60.746220          0
# ACTTGTTCATGGTTGT-DGRP-551_0d_r1 -39.051517 -22.600597         -1
# ACTTTCATCAATAAGG-DGRP-551_0d_r1 -42.696602 -63.323502          1
# AGATCTGCAACAACCT-DGRP-551_0d_r1 -95.983604   3.561458         -1
# AGATCTGTCTACTCAT-DGRP-551_0d_r1   4.488102  93.785294         -1
# AGCGGTCCATTTCACT-DGRP-551_0d_r1  16.568670  93.438782          5
# AGCTCTCGTTTGACTG-DGRP-551_0d_r1  13.434147 -12.280786         31
# AGGTCATGTCAGAATA-DGRP-551_0d_r1 -67.204689 -25.681885         13
# ATCCACCCAGACACTT-DGRP-551_0d_r1  29.265194 -58.666260          0
# ATGGGAGAGGAATGGA-DGRP-551_0d_r1 -52.340363 -64.450005         -1
# ATGTGTGGTCACCCAG-DGRP-551_0d_r1 -18.208292 -76.556633         -1
# ATTGGACAGCTTATCG-DGRP-551_0d_r1 -50.536530  -8.793194         17
# CACCACTCACTCAGGC-DGRP-551_0d_r1  -0.162393  99.572281         -1
# CAGATCACAGATCTGT-DGRP-551_0d_r1 -29.040129 -48.938248         -1
# CAGCTGGTCTACTCAT-DGRP-551_0d_r1  -7.154822 -93.017006         -1
# CAGGTGCAGGGATGGG-DGRP-551_0d_r1 -47.891724 -36.563995         13
# CCGTGGACAAAGGTGC-DGRP-551_0d_r1 -49.667801 -43.812984          7
# CCTAAAGGTCAGATAA-DGRP-551_0d_r1 -81.980675  26.957502         -1
# CCTCAGTCATTATCTC-DGRP-551_0d_r1 -75.373726  -2.965672         -1
# CCTCAGTTCCAAGCCG-DGRP-551_0d_r1 -62.002949 -34.497921         -1
# CGAGAAGAGAATAGGG-DGRP-551_0d_r1 -35.048645 -31.699768         13
# CGATTGATCCGAACGC-DGRP-551_0d_r1 -56.154331 -13.853292         17
# CGTCACTGTCGAGATG-DGRP-551_0d_r1 -40.973724 -33.794689         13
# CTACATTAGCTGCCCA-DGRP-551_0d_r1  31.303951 -39.376762         -1
# CTAGCCTCATACGCCG-DGRP-551_0d_r1  -0.272856  95.197296         -1
# CTCATTAAGATCTGAA-DGRP-551_0d_r1  32.336182  89.144257         -1
# CTCGAGGGTAACGACG-DGRP-551_0d_r1 -69.436508  34.737362         -1
# ...                                    ...        ...        ...
# TGCTGCTAGGTGCACA-w1118_9d_r3     81.484299  23.208216         -1
# TGGACGCTCAAACGGG-w1118_9d_r3      0.222310 -66.238258          2
# TGGACGCTCGTATCAG-w1118_9d_r3     -7.441683 -23.549917         30
# TGGCGCATCGATAGAA-w1118_9d_r3     17.403116 -29.994484         28
# TGGGAAGGTCTGCCAG-w1118_9d_r3     43.467587  70.647324         -1
# TGGTTCCGTGACGCCT-w1118_9d_r3     16.617807  49.177975         10
# TTAACTCAGGCTCAGA-w1118_9d_r3    -26.054604   0.021176         24
# TTAGGACGTACTTGAC-w1118_9d_r3     38.662800  33.663528         -1
# TTCCCAGCATACAGCT-w1118_9d_r3     55.373463 -16.913717         14
# TTGAACGGTCTAAAGA-w1118_9d_r3     66.624886   8.255171         -1
# TTGACTTGTCGTCTTC-w1118_9d_r3    -32.816597  75.055130         -1
# TTGACTTTCAGCGATT-w1118_9d_r3     57.116707  57.719025          3
# TTGTAGGAGGAGCGAG-w1118_9d_r3     52.516544  29.554605         -1
# TTTGCGCGTTAAGACA-w1118_9d_r3     32.372475  44.203175         10
# ACGATACCAAACAACA-w1118_15d_r1    52.218555  29.899717         -1
# CGCCAAGCATTTCACT-w1118_15d_r1    53.917053  74.131195         -1
# CTAAGACCAGCTGCTG-w1118_15d_r1    16.971224 -10.395137         31
# CTACCCACAAGCCCAC-w1118_15d_r1    87.865417 -26.887699         -1
# GAACCTAGTCCGACGT-w1118_15d_r1    38.467514 -11.871377         18
# GAGTCCGAGGTGCAAC-w1118_15d_r1    12.639116  -5.414952         29
# GGCAATTCATGGATGG-w1118_15d_r1   -25.127050   1.487494         24
# GTCCTCAGTTGCGCAC-w1118_15d_r1    64.234909  53.166805          3
# GTGCAGCGTACCGTAT-w1118_15d_r1    64.869781   9.096468         27
# TATGCCCTCTATGTGG-w1118_15d_r1    66.965179 -21.654970         -1
# TCATTACAGAGGTTGC-w1118_15d_r1   -17.508556  60.404091         -1
# TCGAGGCAGCTATGCT-w1118_15d_r1    84.196869  -3.645056         -1
# TTCTACATCAGTGTTG-w1118_15d_r1    10.424765  11.328525         -1
# AAGTCTGTCTGGTTCC-w1118_30d_r1   -36.284100 -41.468407         13
# ACATACGTCGGATGGA-w1118_30d_r1    41.022717  26.891352         23
# GAAATGACAAGACACG-w1118_30d_r1    -8.510668  31.522984         21
#
# [2847 rows x 11 columns]
