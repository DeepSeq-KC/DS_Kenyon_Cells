# %%
library(dplyr)
library(ggplot2)

df <- read.csv("../data/04_synaptic_gene_expression_profiling/CLEAN_LOG2TRANSFORM_WITHEXPRESSION_kenyon_cells.csv")

# %%
# Out:
#  [1] "CellID"       "Unnamed..0"   "Age"          "Gender"       "Genotype"
#  [6] "Replicate"    "nGene"        "nUMI"         "cell_type_id" "is_kc"
# [11] "x"            "y"            "hdb_clust"    "Rim"          "DAT"
# [16] "Pgk"          "Arf79F"       "veli"         "Pka.R1"       "Rop"
# [21] "Rbp"          "Syx1A"        "nAChRalpha3"  "CaMKII"       "gammaSnap1"
# [26] "Sytalpha"     "CanB"         "dlg1"         "sesB"         "nAChRalpha7"
# [31] "VGlut"

# %%
df %>%
  ggplot() +
  geom_point(aes(x=x, y=y, color=Rim, shape=factor(cell_type_id)))
# Out:
# plot without title

# %%
df %>%
  ggplot() +
  geom_point(aes(x=x, y=y, color=DAT, shape=factor(cell_type_id)))
# Out:
# plot without title

# %%
df %>%
  ggplot() +
  geom_point(aes(x=x, y=y, color=Pgk, shape=factor(cell_type_id)))
# Out:
# plot without title

# %%
df %>%
  ggplot() +
  geom_point(aes(x=x, y=y, color=Arf79F, shape=factor(cell_type_id)))
# Out:
# plot without title

# %%
df %>%
  ggplot() +
  geom_point(aes(x=x, y=y, color=veli, shape=factor(cell_type_id)))
# Out:
# plot without title

# %%
df %>%
  ggplot() +
  geom_point(aes(x=x, y=y, color=Pka.R1, shape=factor(cell_type_id)))
# Out:
# plot without title

# %%
df %>%
  ggplot() +
  geom_point(aes(x=x, y=y, color=Rop, shape=factor(cell_type_id)))
# Out:
# plot without title

# %%
df %>%
  ggplot() +
  geom_point(aes(x=x, y=y, color=Rbp, shape=factor(cell_type_id)))
# Out:
# plot without title
