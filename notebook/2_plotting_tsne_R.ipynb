# %%
library(dplyr)
library(ggplot2)

# %%
df <- read.csv("../data/03_ICIM_analysis/KC_ICIM_TSNE_data.csv")

# %%
df %>%
  ggplot() +
  geom_point(aes(x=x, y=y, color=factor(cell_type_id)))
# Out:
# plot without title

# %%
df %>%
  ggplot() +
  geom_point(aes(x=x, y=y, color=factor(hdb_clust))) +
  theme(legend.position = 'none')
# Out:
# plot without title

# %%
df %>%
  ggplot() +
  geom_point(aes(x=x, y=y, color=factor(Age)))
# Out:
# plot without title

# %%
df %>%
  ggplot() +
  geom_point(aes(x=x, y=y, color=factor(Genotype)))
# Out:
# plot without title
